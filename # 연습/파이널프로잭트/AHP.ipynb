# %% [markdown]
# ⚫ 1단계 : 문제 정의 및 목표 설정 : 선정한 변수들 중 범죄 발생에 가장 영향을 크게 미치는 요인들의 상대적 중요도를 정한다
#
# ⚫ 2단계 : 계층구조 만들기  + 작성
#
# ![image.png](attachment:image.png)
#
# ⚫ 3단계 : 비교 행렬 작성하기
# 상대적 중요도에 대한 점수를 행렬화시킴
#
# ⚫ 4단계 : 상대적 중요도 산출
#
# ⚫ 5단계：정합성(일관성) 검증(CI)
# ![image-2.png](attachment:image-2.png)
#
#
# ⚫ 6단계 : 최종 우선순위 도출 및 대안 선정
# ![image-3.png](attachment:image-3.png)
