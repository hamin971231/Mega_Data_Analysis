# %%
import pandas as pd

# %%
hmotel = pd.read_excel('숙박업소_현황.xlsx')
hmotel.head()
# Out:
#    Unnamed: 0  개방자치단체코드                    관리번호  영업상태명 상세영업상태명    소재지면적  \
# 0           0   3010000  3010000-214-2021-00001  영업/정상      영업  1350.84
# 1           1   3010000  3010000-201-2019-00008  영업/정상      영업   610.66
# 2           2   3010000  3010000-214-2023-00002  영업/정상      영업  2808.85
# 3           3   3010000  3010000-201-2017-00010  영업/정상      영업   178.54
# 4           4   3010000  3010000-201-2017-00011  영업/정상      영업   166.54
#
#                        지번주소                                 도로명주소  \
# 0        서울특별시 중구 인현동1가 158        서울특별시 중구 충무로 24, 3~17층 (인현동1가)
# 1       서울특별시 중구 남산동2가 35-2  서울특별시 중구 퇴계로18길 43, 지층, 1~2층 (남산동2가)
# 2        서울특별시 중구 남대문로3가 94             서울특별시 중구 남대문로 27 (남대문로3가)
# 3  서울특별시 중구 남산동2가 33-3 1~2층      서울특별시 중구 퇴계로18길 41 (남산동2가, 1~2층)
# 4    서울특별시 중구 남산동2가 33 1,2층      서울특별시 중구 퇴계로18길 37 (남산동2가, 1,2층)
#
#                  사업장명    업태구분명        좌표정보(X)        좌표정보(Y)      시   구  \
# ...

# %%
len(hmotel.loc[hmotel['지번주소'].isnull(),:])
# Out:
# 11

# %%
hmotel.loc[hmotel['지번주소'].isnull(),:]
# Out:
#       Unnamed: 0  개방자치단체코드                    관리번호  영업상태명 상세영업상태명  \
# 74            75   3180000  3180000-201-2016-00003  영업/정상      영업
# 169          170   3180000  3180000-201-2015-00009  영업/정상      영업
# 229          232   3000000  3000000-201-2015-00001     폐업      폐업
# 275          279   3000000  3000000-201-2014-00001  영업/정상      영업
# 395          417   3160000  3160000-201-2014-00001  영업/정상      영업
# 637          688   3000000  3000000-201-2014-00003  영업/정상      영업
# 647          698   3000000  3000000-201-2001-00378  영업/정상      영업
# 830          910   3000000  3000000-214-2014-00001     폐업      폐업
# 4210        4772   3180000  3180000-201-2016-00004  영업/정상      영업
# 4235        4798   3180000  3180000-201-2015-00007  영업/정상      영업
# 4577        5188   3180000  3180000-214-2016-00001     폐업      폐업
#
#             소재지면적 지번주소                                        도로명주소  \
# 74         511.89  NaN               서울특별시 영등포구 영중로4길 15-7 (영등포동3가)
# ...

# %%
hmotel.isnull().sum()
# Out:
# Unnamed: 0       0
# 개방자치단체코드         0
# 관리번호             0
# 영업상태명            0
# 상세영업상태명          0
# 소재지면적            5
# 지번주소            11
# 도로명주소         1961
# 사업장명             0
# 업태구분명            0
# 좌표정보(X)          0
# 좌표정보(Y)          0
# 시             1961
# 구             1961
# 상세주소          1961
# dtype: int64

# %%
for i,v in enumerate(hmotel.loc[hmotel['도로명주소'].isnull(),'지번주소'].str.split(' ')) :
    hmotel.loc[hmotel['도로명주소'].isnull(),'시'] = v[0]
    hmotel.loc[hmotel['도로명주소'].isnull(),'구'] = v[1]
    hmotel.loc[hmotel['도로명주소'].isnull(),'상세주소'] = v[2]
    # print(v[2])


hmotel.loc[hmotel['도로명주소'].isnull(),:]
# Out:
#       Unnamed: 0  개방자치단체코드                    관리번호 영업상태명 상세영업상태명   소재지면적  \
# 295          301   3000000  3000000-201-1980-00038    폐업      폐업   60.12
# 328          340   3000000  3000000-201-1967-00346    폐업      폐업   31.96
# 330          344   3000000  3000000-201-1979-00348    폐업      폐업   66.27
# 331          345   3000000  3000000-201-1987-00260    폐업      폐업  573.49
# 332          346   3000000  3000000-201-1986-00138    폐업      폐업   80.28
# ...          ...       ...                     ...   ...     ...     ...
# 5930        6654   3240000  3240000-201-1989-00076    폐업      폐업  799.92
# 5931        6655   3240000  3240000-201-1989-00075    폐업      폐업  641.36
# 5934        6658   3240000  3240000-201-1989-00101    폐업      폐업  821.32
# 5935        6659   3240000  3240000-201-1989-00073    폐업      폐업  526.20
# 5936        6660   3240000  3240000-201-1988-00072    폐업      폐업  799.09
#
#                          지번주소 도로명주소    사업장명 업태구분명        좌표정보(X)  \
# ...

# %%
hmotel.to_excel('숙박업소_현황.xlsx')

# %%
test['숙박업소개수']=test['Unnamed: 0']
숙박업소_구단위_현황 = test.iloc[:-1,[-1]]
숙박업소_구단위_현황
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Hamin\Data_Analysis\# 연습\파이널프로잭트\숙박(구)_group.ipynb 셀 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hamin/Data_Analysis/%23%20%EC%97%B0%EC%8A%B5/%ED%8C%8C%EC%9D%B4%EB%84%90%ED%94%84%EB%A1%9C%EC%9E%AD%ED%8A%B8/%EC%88%99%EB%B0%95%28%EA%B5%AC%29_group.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> test['숙박업소개수']=test['Unnamed: 0']
#       <a href='vscode-notebook-cell:/c%3A/Users/Hamin/Data_Analysis/%23%20%EC%97%B0%EC%8A%B5/%ED%8C%8C%EC%9D%B4%EB%84%90%ED%94%84%EB%A1%9C%EC%9E%AD%ED%8A%B8/%EC%88%99%EB%B0%95%28%EA%B5%AC%29_group.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> 숙박업소_구단위_현황 = test.iloc[:-1,[-1]]
# ...

# %%
숙박업소_구단위_현황.to_excel('숙박업소_구단위_현황.xlsx')

# %%
숙박업소_구단위_현황
# Out:
#       숙박업소개수
# 구
# 강남구      206
# 강동구     2092
# 강북구      214
# 강서구      214
# 관악구      232
# 광진구      134
# 구로구      157
# 금천구      110
# 노원구       42
# 도봉구       44
# 동대문구     241
# 동작구       72
# 마포구      116
# 서대문구     123
# 서초구       95
# 성동구      113
# 성북구      144
# 송파구      139
# 양천구       32
# 영등포구     315
# 용산구      121
# 은평구      116
# 종로구      307
# 중구       433
# 중랑구      139
