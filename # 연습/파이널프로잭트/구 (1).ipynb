# %%
import pandas as pd
from pandas import DataFrame
from pandas import read_csv, read_excel
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
train = pd.read_excel('순위.xlsx', index_col='Unnamed: 0')
train
# Out:
#       범죄합계  여자비율  취약계층  숙박업소  유흥업소  다세대주택  단독주택
# 종로구      1    18    22    13     5     23    23
# 중구       2    24    25     5     3     25    24
# 용산구      3    17    19     3    18     18    10
# 양천구      4    16    20     9    25      8    20
# 성동구      5    12    17     7    21     24    14
# 은평구      6     2    10    17    10      3     7
# 서대문구     7     1    12    12    16     15    11
# 성북구      8     3     9    21    24     13     1
# 중랑구      9    10    18     2    20     12     3
# 동대문구    10     9    15    10     9     21     5
# 동작구     11    15    11    25    15     11     8
# 구로구     12    19    16    18    17     19    13
# 관악구     13    23     3     4     4      5     2
# 서초구     14    20    14    14    12     14    25
# 광진구     15     7     7    22    23      7     6
# 강동구     16    13     8     6     1      9    16
# 강남구     17    22     2     1     2      6    21
# 영등포구    18    21     6    24     6     20     9
# 송파구     19    14     1    23     8      1    19
# 금천구     20    25    24    15    14     17    17
# 강북구     21     5    21    11    11     10     4
# 노원구     22     6    13    19    19     22    22
# 마포구     23     4     5    16    13      4    12
# 강서구     24    11     4     8     7      2    15
# 도봉구     25     8    23    20    22     16    18

# %%
train['합계'] = train.loc[:, '범죄합계':'단독주택'].sum(axis=1)
train['합계']
# Out:
# 종로구     105
# 중구      108
# 용산구      88
# 양천구     102
# 성동구     100
# 은평구      55
# 서대문구     74
# 성북구      79
# 중랑구      74
# 동대문구     79
# 동작구      96
# 구로구     114
# 관악구      54
# 서초구     113
# 광진구      87
# 강동구      69
# 강남구      71
# 영등포구    104
# 송파구      85
# 금천구     132
# 강북구      83
# 노원구     123
# 마포구      77
# 강서구      71
# 도봉구     132
# Name: 합계, dtype: int64
