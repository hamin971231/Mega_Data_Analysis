# %%
import pandas as pd

# %%
bell = pd.read_excel('안전비상벨위치정보.xlsx')
bell.head()
# Out:
# c:\Users\Hamin\AppData\Local\Programs\Python\Python39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    번호 안전비상벨관리번호 설치목적 설치장소유형                                설치위치  \
# 0   1     A2041  방범용     공원    서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)
# 1   2     A2042  방범용     공원         서울특별시 관악구 당곡2길 112 (상도근린공원)
# 2   3     A3001  방범용     공원    서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)
# 3   4     A3002  방범용     공원   서울특별시 관악구 난곡동 산 90-2 (일삼별공원 농구코트)
# 4   5     A3003  방범용     공원  서울특별시 관악구 남현동 산 65 (관음사지구 둘레길화장실앞)
#
#                            소재지도로명주소                             소재지지번주소  \
# 0  서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)                                 NaN
# 1       서울특별시 관악구 당곡2길 112 (상도근린공원)                                 NaN
# 2  서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)                                 NaN
# ...

# %%
bell[['시','구','동']] = bell['설치위치'].str.split(" ",n=2,expand=True)

# %%
bell.drop('동',axis=1,inplace=True)

# %%
bell.head()
# Out:
#    번호 안전비상벨관리번호 설치목적 설치장소유형                                설치위치  \
# 0   1     A2041  방범용     공원    서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)
# 1   2     A2042  방범용     공원         서울특별시 관악구 당곡2길 112 (상도근린공원)
# 2   3     A3001  방범용     공원    서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)
# 3   4     A3002  방범용     공원   서울특별시 관악구 난곡동 산 90-2 (일삼별공원 농구코트)
# 4   5     A3003  방범용     공원  서울특별시 관악구 남현동 산 65 (관음사지구 둘레길화장실앞)
#
#                            소재지도로명주소                             소재지지번주소  \
# 0  서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)                                 NaN
# 1       서울특별시 관악구 당곡2길 112 (상도근린공원)                                 NaN
# 2  서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)                                 NaN
# 3                               NaN   서울특별시 관악구 난곡동 산 90-2 (일삼별공원 농구코트)
# 4                               NaN  서울특별시 관악구 남현동 산 65 (관음사지구 둘레길화장실앞)
#
#      WGS84위도     WGS84경도 연계방식  ... 관리사무소연계유무  부가기능 안전비상벨설치연도      최종점검일자  \
# ...

# %%
len(bell['구'].unique())
# Out:
# 3405

# %%
bell.columns
# Out:
# Index(['번호', '안전비상벨관리번호', '설치목적', '설치장소유형', '설치위치', '소재지도로명주소', '소재지지번주소',
#        'WGS84위도', 'WGS84경도', '연계방식', '경찰연계유무', '경비업체연계유무', '관리사무소연계유무', '부가기능',
#        '안전비상벨설치연도', '최종점검일자', '최종점검결과구분', '관리기관명', '관리기관전화번호', '데이터기준일자', '시',
#        '구'],
#       dtype='object')

# %%
len(bell)
# Out:
# 21713

# %%
bell.value_counts('구')
# Out:
# 구
# 강남구      2363
# 관악구       989
# 강서구       980
# 송파구       881
# 앞         830
#          ...
# 37-39       1
# 37-52       1
# 37-7        1
# 37-80       1
# 46-4        1
# Name: count, Length: 3404, dtype: int64
