# %%
import pandas as pd

# %%
hmotel = pd.read_excel('숙박업소_현황.xlsx')
hmotel.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  개방자치단체코드                    관리번호  \
# 0             0             0           0   3010000  3010000-214-2021-00001
# 1             1             1           1   3010000  3010000-201-2019-00008
# 2             2             2           2   3010000  3010000-214-2023-00002
# 3             3             3           3   3010000  3010000-201-2017-00010
# 4             4             4           4   3010000  3010000-201-2017-00011
#
#    영업상태명 상세영업상태명    소재지면적                      지번주소  \
# 0  영업/정상      영업  1350.84        서울특별시 중구 인현동1가 158
# 1  영업/정상      영업   610.66       서울특별시 중구 남산동2가 35-2
# 2  영업/정상      영업  2808.85        서울특별시 중구 남대문로3가 94
# 3  영업/정상      영업   178.54  서울특별시 중구 남산동2가 33-3 1~2층
# 4  영업/정상      영업   166.54    서울특별시 중구 남산동2가 33 1,2층
#
#                                   도로명주소                사업장명    업태구분명  \
# 0        서울특별시 중구 충무로 24, 3~17층 (인현동1가)            어반스테이 명동  숙박업(생활)
# ...

# %%
hmotel[['시','구','동','상세주소2']] = hmotel['지번주소'].str.split(" ",n=3,expand=True)
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  개방자치단체코드  \
# 0                0             0           0   3010000
# 1                1             1           1   3010000
# 2                2             2           2   3010000
# 3                3             3           3   3010000
# 4                4             4           4   3010000
# ...            ...           ...         ...       ...
# 5947          5947          5947        6671   3000000
# 5948          5948          5948        6672   3150000
# 5949          5949          5949        6673   3190000
# 5950          5950          5950        6674   3070000
# 5951          5951          5951        6675   3220000
#
#                         관리번호  영업상태명 상세영업상태명      소재지면적  \
# 0     3010000-214-2021-00001  영업/정상      영업    1350.84
# 1     3010000-201-2019-00008  영업/정상      영업     610.66
# 2     3010000-214-2023-00002  영업/정상      영업    2808.85
# 3     3010000-201-2017-00010  영업/정상      영업     178.54
# ...

# %%
hmotel.drop('상세주소2',axis=1,inplace=True)

# %%
hmotel.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  개방자치단체코드                    관리번호  \
# 0             0             0           0   3010000  3010000-214-2021-00001
# 1             1             1           1   3010000  3010000-201-2019-00008
# 2             2             2           2   3010000  3010000-214-2023-00002
# 3             3             3           3   3010000  3010000-201-2017-00010
# 4             4             4           4   3010000  3010000-201-2017-00011
#
#    영업상태명 상세영업상태명    소재지면적                      지번주소  \
# 0  영업/정상      영업  1350.84        서울특별시 중구 인현동1가 158
# 1  영업/정상      영업   610.66       서울특별시 중구 남산동2가 35-2
# 2  영업/정상      영업  2808.85        서울특별시 중구 남대문로3가 94
# 3  영업/정상      영업   178.54  서울특별시 중구 남산동2가 33-3 1~2층
# 4  영업/정상      영업   166.54    서울특별시 중구 남산동2가 33 1,2층
#
#                                   도로명주소                사업장명    업태구분명  \
# 0        서울특별시 중구 충무로 24, 3~17층 (인현동1가)            어반스테이 명동  숙박업(생활)
# ...

# %%
hmotel.isnull().sum()
# Out:
# Unnamed: 0.2       0
# Unnamed: 0.1       0
# Unnamed: 0         0
# 개방자치단체코드           0
# 관리번호               0
# 영업상태명              0
# 상세영업상태명            0
# 소재지면적              5
# 지번주소              11
# 도로명주소           1961
# 사업장명               0
# 업태구분명              0
# 좌표정보(X)            0
# 좌표정보(Y)            0
# 시                 11
# 구                 11
# 동                 11
# dtype: int64

# %%
hmotel.loc[hmotel['지번주소'].isnull(),"도로명주소"]
# Out:
# 74                   서울특별시 영등포구 영중로4길 15-7 (영등포동3가)
# 169                   서울특별시 영등포구 영신로34길 33 (영등포동4가)
# 229                      서울특별시 종로구 종로 294, 4층 (창신동)
# 275                       서울특별시 종로구 수표로18길 26 (관수동)
# 395     서울특별시 구로구 디지털로 300 (구로동, (주)호텔롯데 롯데시티호텔 구로)
# 637                         서울특별시 종로구 율곡로 179 (원남동)
# 647                        서울특별시 종로구 율곡로6길 19 (운니동)
# 830                     서울특별시 종로구 창경궁로16가길 30 (연지동)
# 4210                     서울특별시 영등포구 선유로 100 (양평동1가)
# 4235                서울특별시 영등포구 영등포로 264-11 (영등포동3가)
# 4577                   서울특별시 영등포구 양평로28길 11 (양평동6가)
# Name: 도로명주소, dtype: object

# %%
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영중로4길 15-7 (영등포동3가)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영중로4길 15-7 (영등포동3가)','구'] = '영등포구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영중로4길 15-7 (영등포동3가)','동'] = '영등포동3가'

hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영신로34길 33 (영등포동4가)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영신로34길 33 (영등포동4가)','구'] = '영등포구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영신로34길 33 (영등포동4가)','동'] = '영등포동4가'

hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 종로 294, 4층 (창신동)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 종로 294, 4층 (창신동)','구'] = '종로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 종로 294, 4층 (창신동)','동'] = '창신동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 수표로18길 26 (관수동)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 수표로18길 26 (관수동)','구'] = '종로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 수표로18길 26 (관수동)','동'] = '관수동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 구로구 디지털로 300 (구로동, (주)호텔롯데 롯데시티호텔 구로)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 구로구 디지털로 300 (구로동, (주)호텔롯데 롯데시티호텔 구로)','구'] = '구로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 구로구 디지털로 300 (구로동, (주)호텔롯데 롯데시티호텔 구로)','동'] = '구로동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로 179 (원남동)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로 179 (원남동)','구'] = '종로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로 179 (원남동)','동'] = '원남동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로6길 19 (운니동)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로6길 19 (운니동)','구'] = '종로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 율곡로6길 19 (운니동)','동'] = '운니동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 창경궁로16가길 30 (연지동)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 창경궁로16가길 30 (연지동)','구'] = '종로구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 종로구 창경궁로16가길 30 (연지동)','동'] = '연지동'

hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 선유로 100 (양평동1가)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 선유로 100 (양평동1가)','구'] = '영등포구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 선유로 100 (양평동1가)','동'] = '양평동1가'

hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영등포로 264-11 (영등포동3가)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영등포로 264-11 (영등포동3가)','구'] = '영등포구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 영등포로 264-11 (영등포동3가)','동'] = '영등포동3가'

hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 양평로28길 11 (양평동6가)','시'] = '서울특별시'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 양평로28길 11 (양평동6가)','구'] = '영등포구'
hmotel.loc[hmotel['도로명주소']=='서울특별시 영등포구 양평로28길 11 (양평동6가)','동'] = '양평동6가'

# %%
hmotel.isnull().sum()
# Out:
# Unnamed: 0.2       0
# Unnamed: 0.1       0
# Unnamed: 0         0
# 개방자치단체코드           0
# 관리번호               0
# 영업상태명              0
# 상세영업상태명            0
# 소재지면적              5
# 지번주소              11
# 도로명주소           1961
# 사업장명               0
# 업태구분명              0
# 좌표정보(X)            0
# 좌표정보(Y)            0
# 시                  0
# 구                  0
# 동                  0
# dtype: int64

# %%
hmotel.to_excel('숙박업소_현황.xlsx')

# %%
test=hmotel.groupby(['구']).count()

# %%
test['숙박업소개수']=test['Unnamed: 0']
숙박업소_구단위_현황 = test.iloc[:-1,[-1]]
숙박업소_구단위_현황
# Out:
#       숙박업소개수
# 구
# 강남구      324
# 강동구      240
# 강북구      288
# 강서구      264
# 관악구      414
# 광진구      170
# 구로구      238
# 금천구      151
# 노원구       49
# 도봉구       61
# 동대문구     320
# 동작구      124
# 마포구      184
# 서대문구     205
# 서초구      123
# 성동구      252
# 성북구      261
# 송파구      195
# 양천구       49
# 영등포구     429
# 용산구      312
# 은평구      155
# 종로구      472
# 중구       480
# 중랑구      191

# %%
숙박업소_구단위_현황.to_excel('숙박업소_구단위_현황.xlsx')

# %%
숙박업소_구단위_현황
# Out:
#       숙박업소개수
# 구
# 강남구      324
# 강동구      240
# 강북구      288
# 강서구      264
# 관악구      414
# 광진구      170
# 구로구      238
# 금천구      151
# 노원구       49
# 도봉구       61
# 동대문구     320
# 동작구      124
# 마포구      184
# 서대문구     205
# 서초구      123
# 성동구      252
# 성북구      261
# 송파구      195
# 양천구       49
# 영등포구     429
# 용산구      312
# 은평구      155
# 종로구      472
# 중구       480
# 중랑구      191
