# %%
import pandas as pd 

df = pd.read_excel(r"C:\Users\Hamin\Desktop\서울시_빌딩.xlsx")
df.head()
# Out:
#    BDTYP_CD                  BD_MGT_SN  BSI_INT_SN  BSI_ZON_NO  BULD_MNNM  \
# 0      6999  1111013600100990000015925       17341        3164        401
# 1      6999  1111013600100990000015380       17341        3164        401
# 2      6999  1111013600100920000014237       13640        3164        401
# 3      3999  1111013600100780001017266       16387        3164        403
# 4      4999  1111013600100750004017367       16387        3164        403
#
#   BULD_NM BULD_NM_DC  BULD_SE_CD  BULD_SLNO BUL_DPN_SE  ...  BLK_CD  \
# 0     NaN        NaN           0         44          M  ...  349865
# 1     NaN        NaN           0         44          M  ...  349865
# 2     NaN        NaN           0         48          M  ...  349865
# 3     NaN        NaN           0          0          M  ...  349865
# 4     NaN        NaN           0          1          M  ...  349865
#
#            OA_CD  FL_UP_NEW  FL_DN_NEW  USE_CD_NEW    XMIN    YMIN    XMAX  \
# ...

# %%
df['USE_CD_NEW'].head()
# Out:
# 0    6999
# 1    6999
# 2    6999
# 3    3999
# 4    4999
# Name: USE_CD_NEW, dtype: int64

# %%
house_1 = df.loc[(df['USE_CD_NEW']==1001),:]
house_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153419 entries, 6 to 654593
# Data columns (total 36 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BDTYP_CD    153419 non-null  int64
#  1   BD_MGT_SN   153419 non-null  object
#  2   BSI_INT_SN  153419 non-null  int64
#  3   BSI_ZON_NO  153419 non-null  int64
#  4   BULD_MNNM   153419 non-null  int64
#  5   BULD_NM     1616 non-null    object
#  6   BULD_NM_DC  1483 non-null    object
#  7   BULD_SE_CD  153419 non-null  int64
#  8   BULD_SLNO   153419 non-null  int64
#  9   BUL_DPN_SE  153419 non-null  object
#  10  BUL_MAN_NO  153419 non-null  int64
#  11  EMD_CD      153419 non-null  int64
#  12  GRO_FLO_CO  153419 non-null  int64
#  13  LI_CD       153419 non-null  int64
#  14  LNBR_MNNM   153419 non-null  int64
#  15  LNBR_SLNO   153419 non-null  int64
#  16  MNTN_YN     153419 non-null  int64
#  17  RN_CD       153419 non-null  int64
#  18  SIG_CD      153419 non-null  int64
# ...

# %%
# Out:
# 6         1001
# 23        1001
# 69        1001
# 70        1001
# 71        1001
#           ...
# 654547    2003
# 654577    2003
# 654579    2003
# 654582    2003
# 654590    2003
# Name: USE_CD_NEW, Length: 269886, dtype: int64

# %%
house_2 = df.loc[(df['USE_CD_NEW']==2001),:]
house_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34508 entries, 230 to 654554
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BDTYP_CD    34508 non-null  int64
#  1   BD_MGT_SN   34508 non-null  object
#  2   BSI_INT_SN  34508 non-null  int64
#  3   BSI_ZON_NO  34508 non-null  int64
#  4   BULD_MNNM   34508 non-null  int64
#  5   BULD_NM     29208 non-null  object
#  6   BULD_NM_DC  22658 non-null  object
#  7   BULD_SE_CD  34508 non-null  int64
#  8   BULD_SLNO   34508 non-null  int64
#  9   BUL_DPN_SE  34508 non-null  object
#  10  BUL_MAN_NO  34508 non-null  int64
#  11  EMD_CD      34508 non-null  int64
#  12  GRO_FLO_CO  34508 non-null  int64
#  13  LI_CD       34508 non-null  int64
#  14  LNBR_MNNM   34508 non-null  int64
#  15  LNBR_SLNO   34508 non-null  int64
#  16  MNTN_YN     34508 non-null  int64
#  17  RN_CD       34508 non-null  int64
#  18  SIG_CD      34508 non-null  int64
# ...

# %%
house_3 = df.loc[(df['USE_CD_NEW']==2003),:]
house_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81959 entries, 89 to 654590
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BDTYP_CD    81959 non-null  int64
#  1   BD_MGT_SN   81959 non-null  object
#  2   BSI_INT_SN  81959 non-null  int64
#  3   BSI_ZON_NO  81959 non-null  int64
#  4   BULD_MNNM   81959 non-null  int64
#  5   BULD_NM     21787 non-null  object
#  6   BULD_NM_DC  11036 non-null  object
#  7   BULD_SE_CD  81959 non-null  int64
#  8   BULD_SLNO   81959 non-null  int64
#  9   BUL_DPN_SE  81959 non-null  object
#  10  BUL_MAN_NO  81959 non-null  int64
#  11  EMD_CD      81959 non-null  int64
#  12  GRO_FLO_CO  81959 non-null  int64
#  13  LI_CD       81959 non-null  int64
#  14  LNBR_MNNM   81959 non-null  int64
#  15  LNBR_SLNO   81959 non-null  int64
#  16  MNTN_YN     81959 non-null  int64
#  17  RN_CD       81959 non-null  int64
#  18  SIG_CD      81959 non-null  int64
# ...

# %%
house = pd.concat([house_1,house_2,house_3])
house.head()
# Out:
#     BDTYP_CD                  BD_MGT_SN  BSI_INT_SN  BSI_ZON_NO  BULD_MNNM  \
# 6       1001  1111013600101100000000001       16389        3164        407
# 23      1001  1111013400100470004014435       16405        3148        439
# 69      1001  1111013600101280001016061       13627        3164        401
# 70      1001  1111013600100790000015851       13629        3164        401
# 71      1001  1111013600100790000016390       13629        3164        401
#
#    BULD_NM BULD_NM_DC  BULD_SE_CD  BULD_SLNO BUL_DPN_SE  ...  BLK_CD  \
# 6      NaN        NaN           0          0          M  ...  349865
# 23     NaN        NaN           0          0          M  ...  353140
# 69     NaN        NaN           0          2          M  ...  349865
# 70     NaN        NaN           0          6          M  ...  349865
# 71     NaN        NaN           0          6          M  ...  349865
#
#             OA_CD  FL_UP_NEW  FL_DN_NEW  USE_CD_NEW    XMIN    YMIN    XMAX  \
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 269886 entries, 6 to 654590
# Data columns (total 36 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BDTYP_CD    269886 non-null  int64
#  1   BD_MGT_SN   269886 non-null  object
#  2   BSI_INT_SN  269886 non-null  int64
#  3   BSI_ZON_NO  269886 non-null  int64
#  4   BULD_MNNM   269886 non-null  int64
#  5   BULD_NM     52611 non-null   object
#  6   BULD_NM_DC  35177 non-null   object
#  7   BULD_SE_CD  269886 non-null  int64
#  8   BULD_SLNO   269886 non-null  int64
#  9   BUL_DPN_SE  269886 non-null  object
#  10  BUL_MAN_NO  269886 non-null  int64
#  11  EMD_CD      269886 non-null  int64
#  12  GRO_FLO_CO  269886 non-null  int64
#  13  LI_CD       269886 non-null  int64
#  14  LNBR_MNNM   269886 non-null  int64
#  15  LNBR_SLNO   269886 non-null  int64
#  16  MNTN_YN     269886 non-null  int64
#  17  RN_CD       269886 non-null  int64
#  18  SIG_CD      269886 non-null  int64
# ...

# %%
house = house.loc[[:,['Buld_PRPORS_CD','BULD_SE_CD','EMD_CD','MNTN_AT','RN_CD','SIGNGU_CD','BULD_XCNTS_CENTER_VALUE','BULD_YDNTS_CENTER_VALUE','ADSTRD_CD']]]

# %%
# house.to_excel('서울시_주택.xlsx')
