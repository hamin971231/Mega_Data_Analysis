# %%
import pandas as pd

# %%
node = pd.read_excel('중구_노드_링크_네트워크데이터.xlsx')

# %%
node = node[(node['노드링크 유형'] == 'NODE') &
        (node['육교'] == 0) &
        (node['횡단보도'] == 0)]

# %%
node
# Out:
#        Unnamed: 0 노드링크 유형                                        노드 WKT  \
# 0               0    NODE  POINT(127.00138520146373 37.568187437157185)
# 1               1    NODE   POINT(127.01697814071575 37.56762896761354)
# 3               3    NODE   POINT(126.97646615812025 37.55427380378025)
# 4               4    NODE   POINT(127.01917432263897 37.56617541509709)
# 5               5    NODE   POINT(126.96329524184776 37.55797263212856)
# ...           ...     ...                                           ...
# 12829       12864    NODE  POINT(127.00671304470401 37.555271976044445)
# 12831       12866    NODE  POINT(127.00609787656336 37.555217084599064)
# 12833       12868    NODE  POINT(127.00662680680709 37.555271980916025)
# 12835       12870    NODE     POINT(127.006744648147 37.55508202591123)
# 12837       12872    NODE   POINT(127.0068510192633 37.555205600630416)
#
#         노드 ID  노드 유형 코드 링크 WKT  링크 ID  링크 유형 코드  시작노드 ID  종료노드 ID  ...  \
# ...

# %%
node.to_csv('설치불가능_제외.csv')
